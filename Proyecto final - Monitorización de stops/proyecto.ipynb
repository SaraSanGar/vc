# %% [markdown]
# ## Configuración del enviroment

# %%
# %pip install opencv_python
# Out:
# Requirement already satisfied: opencv_python in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from opencv_python) (1.26.3)

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (8.0.237)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (3.8.2)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (1.26.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.12.2)
# Requirement already satisfied: colorama in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\saúl\anaconda3\envs\vc\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %% [markdown]
# # Importaciones necesarias

# %%
import math
import cv2
import numpy as np

from ultralytics import YOLO

# %%
# Carga del modelo
model = YOLO('yolov8n.pt')

# %% [markdown]
# # Calculo del punto de detención

# %% [markdown]
# Función auxiliar para determinar la linea de stop y el punto de detención donde se deberá completar la parada para validar el stop del vehiculo

# %%
def set_stop_point(frame):

    img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    img_suavizada = cv2.GaussianBlur(img, (3, 3), 0)
    
    ## Aplicación de sobel
    # Calcula en ambas direcciones (horizontal y vertical)
    sobelx = cv2.Sobel(img_suavizada, cv2.CV_64F, 1, 0)  # x
    sobely = cv2.Sobel(img_suavizada, cv2.CV_64F, 0, 1)  # y
    # Combina ambos resultados
    sobel = cv2.add(sobelx, sobely)
    sobel8 = np.uint8(sobel)
    # Calcula en ambas direcciones (horizontal y vertical)
    sobel8x = np.uint8(sobelx)
    sobel8y = np.uint8(sobely)

    ## Calculos de máximos
    # Calcula el valor máximo en columnas
    max_cols = max([sum(columna) for columna in sobel8y])
    # Calcula el valor máximo en filas
    max_rows = max([sum(fila) for fila in sobel8x])

    index_cols = [index for index,columna in enumerate(sobel8y) if sum(columna) > 0.95*max_cols]
    index_rows = [index for index,fila in enumerate(sobel8x) if sum(fila) > 0.95*max_rows]

    print("Punto de parada:",max(index_cols),max(index_rows))
    return (max(index_cols),max(index_rows))

# %% [markdown]
# # Analisis del movimiento del vehiculo
#
# Ejemplo realizando el stop correctamente

# %%
vid = cv2.VideoCapture("correcto.mp4") #Busca n vídeo propio

stop_point = None
stoped = False
last_point = (0,0)
car_point = (0,0)
frame_counter = 0
frames_stoped_counter = 0
frames_stoped_goal = 50
frame_y_history = []

while(True):
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:

        if stop_point == None:
            stop_point = set_stop_point(frame)

        cv2.circle(frame,stop_point, 8, (255,0,255), -1)
        cv2.putText(frame, "Punto de parada", (stop_point[0], stop_point[1] + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,255), 2)

        # Perform inference on an image
        results = model(frame, stream=True)

        frame_counter += 1

        # Para cada detección
        for r in results:
            boxes = r.boxes
            for box in boxes:
                if int(box.cls[0]) == 2:
                    # Contenedor
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                    # Dibuja el contenedor del coche
                    if stoped:
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)
                    else:
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)

                    # Dibuja punto intermedio coche
                    cv2.circle(frame,(x1+75,y2), 8, (255,0,255), -1)

                    # Guardamos Historico de las posiciones del coche
                    frame_y_history.append(y2)

                    # Contamos el tiempo que pasa el vehiculo parado
                    if frame_counter > 60:
                        if y2 - frame_y_history[-4] <= 1:
                            frames_stoped_counter += 1

                    # Si el vehiculo para suficiente tiempo y a la distancia adecuada de la linea verificamos el stop
                    if y2 >=  stop_point[1] and frames_stoped_counter >= frames_stoped_goal:
                        stoped = True       
                    
                

        if stoped:
            cv2.putText(frame, "Stop completado :)", (30,30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
        else:
            cv2.putText(frame, "Stop no completado :(", (30,30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)

        # Muestra fotograma
        cv2.imshow("correcto",frame)

    # Detenemos pulsado ESC
    if cv2.waitKey(10) == 27:
        break

# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# Punto de parada: 112 451
#
# 0: 640x480 2 motorcycles, 127.1ms
# Speed: 2.0ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 125.1ms
# Speed: 3.0ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 115.1ms
# Speed: 3.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 120.1ms
# Speed: 3.0ms preprocess, 120.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 2 motorcycles, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 119.1ms
# Speed: 2.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 motorcycles, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 cars, 2 motorcycles, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 2 motorcycles, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 117.1ms
# Speed: 3.0ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 116.1ms
# Speed: 3.0ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 115.1ms
# Speed: 3.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 115.1ms
# Speed: 3.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 136.1ms
# Speed: 4.0ms preprocess, 136.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 118.1ms
# Speed: 3.0ms preprocess, 118.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle,
1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 118.1ms
# Speed: 3.0ms preprocess, 118.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 1 bus, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 1 bus, 1 truck, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 1 bus, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 1 motorcycle, 1 bus, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 1 car, 1 motorcycle, 1 bus, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 persons, 1 bicycle, 1 car, 1 motorcycle, 1 bus, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 1 car, 1 motorcycle, 1 bus, 140.1ms
# Speed: 3.0ms preprocess, 140.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 1 bicycle, 1 car, 1 motorcycle, 1 bus, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 1 motorcycle, 1 bus, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 1 motorcycle, 1 train, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 person, 1 car, 2 motorcycles, 1 bus, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 2 motorcycles, 1 bus, 112.1ms
# Speed: 3.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 2 motorcycles, 1 bus, 125.1ms
# Speed: 2.0ms preprocess, 125.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 bicycles, 1 car, 1 motorcycle, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 1 motorcycle, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 2 motorcycles, 112.1ms
# Speed: 2.0ms preprocess, 112.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 bicycles, 1 car, 1 motorcycle, 119.1ms
# Speed: 3.0ms preprocess, 119.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 1 train, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 119.1ms
# Speed: 2.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 car, 2 motorcycles, 133.1ms
# Speed: 4.0ms preprocess, 133.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 bicycle, 1 car, 2 motorcycles, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)

# %% [markdown]
# Ejemplo realizando el stop incorrectamente

# %%
vid = cv2.VideoCapture("incorrecto.mp4") #Busca n vídeo propio

stop_point = None
stoped = False
last_point = (0,0)
car_point = (0,0)
frame_counter = 0
frames_stoped_counter = 0
frames_stoped_goal = 50
frame_y_history = []

while(True):
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:

        if stop_point == None:
            stop_point = set_stop_point(frame)

        cv2.circle(frame,stop_point, 8, (255,0,255), -1)
        cv2.putText(frame, "Punto de parada", (stop_point[0], stop_point[1] + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,255), 2)

        # Perform inference on an image
        results = model(frame, stream=True)

        frame_counter += 1

        # Para cada detección
        for r in results:
            boxes = r.boxes
            for box in boxes:
                if int(box.cls[0]) == 2:
                    # Contenedor
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                    # Dibuja el contenedor del coche
                    if stoped:
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 3)
                    else:
                        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 3)

                    # Dibuja punto intermedio coche
                    cv2.circle(frame,(x1+75,y2), 8, (255,0,255), -1)

                    frame_y_history.append(y2)

                    if frame_counter > 60:
                        if y2 - frame_y_history[-4] <= 1:
                            frames_stoped_counter += 1

                    if y2 >=  stop_point[1] and frames_stoped_counter >= frames_stoped_goal:
                        stoped = True       
                    
                

        if stoped:
            cv2.putText(frame, "Stop completado :)", (30,30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)
        else:
            cv2.putText(frame, "Stop no completado :(", (30,30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)

        # Muestra fotograma
        cv2.imshow("incorrecto",frame)

    # Detenemos pulsado ESC
    if cv2.waitKey(10) == 27:
        break

# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# Punto de parada: 79 477
#
# 0: 640x448 1 bicycle, 2 motorcycles, 125.1ms
# Speed: 3.0ms preprocess, 125.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 137.1ms
# Speed: 3.0ms preprocess, 137.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 116.1ms
# Speed: 3.0ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 181.2ms
# Speed: 2.0ms preprocess, 181.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 109.1ms
# Speed: 3.0ms preprocess, 109.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 motorcycles, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 bicycles, 2 cars, 2 motorcycles, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 bicycles, 1 car, 2 motorcycles, 113.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 2 motorcycles, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 bicycles, 1 car, 2 motorcycles, 109.1ms
# Speed: 3.0ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 2 motorcycles, 103.1ms
# Speed: 3.0ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 bicycles, 1 car, 2 motorcycles, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 107.5ms
# Speed: 2.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 2 cars, 1 motorcycle, 105.1ms
# Speed: 3.0ms preprocess, 105.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 104.1ms
# Speed: 2.0ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 3.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 113.1ms
# Speed: 3.0ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 109.9ms
# Speed: 3.0ms preprocess, 109.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1
6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 1 motorcycle, 109.1ms
# Speed: 2.0ms preprocess, 109.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 1 chair, 109.1ms
# Speed: 2.0ms preprocess, 109.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 1 truck, 1 chair, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 106.1ms
# Speed: 3.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 109.1ms
# Speed: 2.0ms preprocess, 109.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 2 cars, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 1 motorcycle, 1 bus, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 bus, 108.1ms
# Speed: 3.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 bus, 1 truck, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 train, 109.8ms
# Speed: 3.0ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 motorcycle, 1 truck, 108.5ms
# Speed: 3.0ms preprocess, 108.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 109.1ms
# Speed: 3.0ms preprocess, 109.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 111.1ms
# Speed: 3.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 114.1ms
# Speed: 3.0ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 110.2ms
# Speed: 2.0ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.4ms
# Speed: 2.0ms preprocess, 107.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 110.1ms
# Speed: 3.0ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 4.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 3.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 108.1ms
# Speed: 2.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 car, 1 motorcycle, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 car, 1 motorcycle, 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 person, 1 bicycle, 1 car, 1 motorcycle, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 motorcycle, 145.1ms
# Speed: 2.0ms preprocess, 145.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 128.1ms
# Speed: 2.0ms preprocess, 128.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 121.1ms
# Speed: 4.0ms preprocess, 121.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 106.1ms
# Speed: 3.0ms preprocess, 106.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 bicycle, 1 motorcycle, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
